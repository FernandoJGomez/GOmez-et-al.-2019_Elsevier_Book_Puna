# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
location='C:\\Users\\LENOVO\\Documents\\FER_GOMEZ\\Papers_en_preparacion\\Libro Elsevier\\Figures\\LN_Isotopes_plots.csv'

# %%
datos= pd.read_csv(location, encoding= 'utf-8')

# %%
datos
# Out:
#       d13C  d18O
# 0     8.09  0.29
# 1     7.68 -1.32
# 2     8.02  0.46
# 3     6.45 -1.10
# 4     7.77 -0.74
# 5     5.75 -0.85
# 6     7.96 -2.04
# 7     6.52 -0.86
# 8     8.34 -0.71
# 9     8.17 -0.98
# 10    9.20  5.22
# 11    9.21 -0.85
# 12    9.15 -1.33
# 13    9.55  0.09
# 14    9.41 -1.50
# 15    9.41 -0.38
# 16    9.80  2.16
# 17   10.17  3.70
# 18   11.35  1.76
# 19    9.37  0.80
# 20    9.76  5.60
# 21    9.80  0.40
# 22    8.93 -0.53
# 23    9.75 -0.33
# 24    9.99  1.16
# 25    9.90  0.23
# 26    9.15  0.35
# 27   10.43  0.49
# 28   11.72  0.94
# 29   11.02  0.73
# ..     ...   ...
# 288   9.94  0.50
# 289  10.21 -0.08
# 290  11.16  0.77
# 291   9.24 -0.16
# 292   9.86  0.81
# 293   8.92  3.06
# 294   6.53  0.17
# 295   5.92 -0.49
# 296   6.10  0.05
# 297   6.39 -0.30
# 298   9.33  0.89
# 299   7.18  0.58
# 300   8.09  1.61
# 301   7.74  1.23
# 302  12.33  5.18
# 303  10.26  5.19
# 304  11.95  3.70
# 305  10.32  3.09
# 306  11.61  4.18
# 307   7.85  0.74
# ...

# %%
d13C=datos.iloc[:, 0]
d18O=datos.iloc[:, 1]

# %%
plt.scatter(d18O, d13C)
plt.show()

# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set(style="white", color_codes=True)

g = sns.jointplot(x="d18O", y="d13C", data=datos)

# %%
from scipy import stats

slope, intercept, r_value, p_value, std_err = stats.linregress(d18O,d13C)

sns.set(style="darkgrid")
g = sns.jointplot("d18O", "d13C", data=datos, kind="reg")

print('slope=', slope, 'intercept', intercept, 'r_value=', r_value, 'p_value=', p_value, 'std_err=', std_err)
print("y={0:.1f}x+{1:.1f}".format(slope,intercept))

g.savefig("d13C_d18O_histograms.pdf")
# Out:
# slope= 0.7590177682472091 intercept 8.985212193331398 r_value= 0.6487416300113592 p_value= 2.274828972435894e-39 std_err= 0.05008714489309423
# y=0.8x+9.0

# %%
datos.describe()
# Out:
#              d13C        d18O
# count  318.000000  318.000000
# mean    10.034686    1.382673
# std      1.968020    1.682091
# min      4.310000   -2.040000
# 25%      8.730000    0.350000
# 50%      9.865000    1.040000
# 75%     11.012500    1.857500
# max     18.260000    9.280000
