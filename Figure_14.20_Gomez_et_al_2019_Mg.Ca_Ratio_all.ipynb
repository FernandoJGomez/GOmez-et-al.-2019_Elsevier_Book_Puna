# %%
import numpy as np
# `numpy.random` uses its own PRNG.
np.random.seed(444)
np.set_printoptions(precision=3)

d = np.random.laplace(loc=15, scale=3, size=500)
d[:5]
# Out:
# array([18.406, 18.087, 16.004, 16.221,  7.358])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# An "interface" to matplotlib.axes.Axes.hist() method
n, bins, patches = plt.hist(x=d, bins='auto', color='#0504aa',
                            alpha=0.7, rwidth=0.85)
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('My Very Own Histogram')
plt.text(23, 45, r'$\mu=15, b=3$')
maxfreq = n.max()
# Set a clean upper y-axis limit.
plt.ylim(ymax=np.ceil(maxfreq / 10) * 10 if maxfreq % 10 else maxfreq + 10)
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_base.py:3610: MatplotlibDeprecationWarning:
# The `ymax` argument was deprecated in Matplotlib 3.0 and will be removed in 3.2. Use `top` instead.
#   alternative='`top`', obj_type='argument')

# %%
m=np.array([0.582, 0.806, 1.994, 0.578, 0.207, 0.903, 0.930, 0.769,
0.083, 0.658, 1.903, 0.161, 0.655, 2.372, 0.792, 0.552,
0.465, 4.314, 1.074, 7.333, 6.066, 29.897, 1.852, 6.671,
0.583, 0.434, 2.272, 0.600, 7.113, 26.113, 10.595, 1.076,
0.437, 1.543, 1.317, 4.030, 0.355, 5.756, 2.541, 4.259,
32.974, 2.810])
len(m)
# Out:
# 42

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# An "interface" to matplotlib.axes.Axes.hist() method
n, bins, patches = plt.hist(x=m, bins='auto', color='#0504aa',
                            alpha=0.5, rwidth=0.85)
plt.grid(axis='y', alpha=0.95, linestyle='--')
plt.xlabel('Mg/Ca molar ratio')
plt.ylabel('Frequency')
plt.title('Mg/Ca molar ratio (n=42)')
plt.text(2.2, 28, r'$Mg/Ca=2$', color='r')
plt.axvline(x=2, color='r', linestyle='--')
maxfreq = n.max()
# Set a clean upper y-axis limit.
plt.ylim(ymax=np.ceil(maxfreq / 10) * 10 if maxfreq % 10 else maxfreq + 10)
plt.savefig('Mg.Ca_all_lakes.pdf', dpi=200)
plt.show()

# %%
import numpy as np
omega_cal=np.array([
4.17E-06,
1.01E-05,
7.35E+01,
6.39E+00,
1.00E-02,
1.29E+02,
1.70E+02,
8.79E+01,
6.86E+02,
3.80E-04,
1.19E-06,
1.79E+01,
3.96E+00,
1.40E+00,
2.30E-14,
1.19E-08,
6.69E-02,
1.26E-05,
1.72E-04,
5.83E-05,
1.09E-05,
8.86E+01,
4.36E+02,
1.37E+01,
1.04E+00,
2.99E+01,
9.19E+00,
1.17E+00,
9.58E+01,
3.05E+00,
1.15E+01,
7.71E-01,
6.87E+00,
1.46E+01,
7.14E+01,
1.09E+01,
2.47E+02,
9.27E-01,
1.68E+00,
3.81E+01,
1.05E+02,
6.41E+01
])

SI=np.log10(omega_cal)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# An "interface" to matplotlib.axes.Axes.hist() method
n, bins, patches = plt.hist(x=SI, bins=40, color='#0504aa',
                            alpha=0.5, rwidth=0.85)
plt.grid(axis='y', alpha=0.95, linestyle='--')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Saturation Index (n=42)')
#plt.text(2.2, 28, r'$Mg/Ca=2$', color='r')
plt.axvline(x=0, color='r', linestyle='--')
maxfreq = n.max()
# Set a clean upper y-axis limit.
plt.ylim(ymax=np.ceil(maxfreq / 10) * 10 if maxfreq % 10 else maxfreq + 10)
plt.savefig('SI_all_lakes.pdf', dpi=200)
plt.show()

# %%
26*100/42
# Out:
# 61.904761904761905

# %%
x=np.linspace(0, 10, 20)
y=0.884*x+0.000118
plt.plot(x, y)
print(x)
print(y)
# Out:
# [ 0.     0.526  1.053  1.579  2.105  2.632  3.158  3.684  4.211  4.737
#   5.263  5.789  6.316  6.842  7.368  7.895  8.421  8.947  9.474 10.   ]
# [1.180e-04 4.654e-01 9.306e-01 1.396e+00 1.861e+00 2.326e+00 2.792e+00
#  3.257e+00 3.722e+00 4.187e+00 4.653e+00 5.118e+00 5.583e+00 6.049e+00
#  6.514e+00 6.979e+00 7.444e+00 7.910e+00 8.375e+00 8.840e+00]

# %%
x/y
# Out:
# array([0.   , 1.131, 1.131, 1.131, 1.131, 1.131, 1.131, 1.131, 1.131,
#        1.131, 1.131, 1.131, 1.131, 1.131, 1.131, 1.131, 1.131, 1.131,
#        1.131, 1.131])

# %%
y/x
# Out:
# C:\Users\LENOVO\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in true_divide
#   """Entry point for launching an IPython kernel.
# array([  inf, 0.884, 0.884, 0.884, 0.884, 0.884, 0.884, 0.884, 0.884,
#        0.884, 0.884, 0.884, 0.884, 0.884, 0.884, 0.884, 0.884, 0.884,
#        0.884, 0.884])

# %%
1.31/2
# Out:
# 0.655

# %%
# Out:
# 1.8985507246376812

# %%
# Out:
# 131.0

# %%
# Out:
# 0.69

# %%
# Out:
# -0.000433587786259542
